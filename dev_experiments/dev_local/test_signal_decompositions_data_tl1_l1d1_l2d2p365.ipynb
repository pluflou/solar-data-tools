# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import signal
from scipy.stats import laplace_asymmetric, laplace

from solardatatools import signal_decompositions as sd

np.random.seed(12) # reload each time to get first instance of seed

# %%
# Generate random numbers
alr = laplace_asymmetric.rvs(kappa=2, size=1000)
lr = laplace.rvs(size=1000)

# %% [markdown]
# # Set up simple numerical examples for tests

# %% [markdown]
# # tl1_l1d1_l2d2p365

# %% [markdown]
# ## Three-Component Signal
# - asymmetric laplacian noise
# - piecewise constant
# - smooth seasonal

# %%
t = np.linspace(0, 1000, 365*2)
signal1 = np.sin(2 * np.pi * t * 1 / (500.))
signal2 = signal.square(2 * np.pi * t * 1 / (450.))
X_real = np.zeros((3, len(t)), dtype=float)
kappa = 2 # shape param
X_real[0] = 0.15 * laplace_asymmetric.rvs(kappa, size=len(signal1))
X_real[1] = signal1
X_real[2] = signal2
y = np.sum(X_real, axis=0)
K, T = X_real.shape

# %%
plt.plot(signal1)
plt.plot(signal2)
plt.plot(X_real[0])

# %% [markdown]
# ## sav/load as df

# %%
fname = "test_tl1_l1d1_l2d2p365_data_input.csv"
# try:
#     signal = pd.read_csv(fname)["test_signal"].array
#     test_df = pd.DataFrame(signal, columns=["test_signal"])
#     #df_full = pd.read_csv(fname)
# except FileNotFoundError:
test_df = pd.DataFrame(y, columns=["test_signal"]).round(7)

# %%
test_df.head(1)
# Out:
#    test_signal
# 0     0.506019

# %%
signal = test_df["test_signal"].array
# cvxpy output w/ default args

# MOSEK
s_hat, s_seas = sd.tl1_l1d1_l2d2p365(signal, c1=1, solver = "MOSEK")
test_df["expected_s_hat_mosek"] = s_hat
test_df["expected_s_seas_mosek"] = s_seas

# SCS 
s_hat, s_seas = sd.tl1_l1d1_l2d2p365(signal, c1=10, solver = "SCS")
test_df["expected_s_hat_scs"] = s_hat
test_df["expected_s_seas_scs"] = s_seas

#############################################################
# w/ random weights 
rand_residual_weights = np.random.uniform(1, 2, len(signal)).round(7)
rand_tv_weights = np.random.uniform(10, 2, len(signal)-1).round(7)
test_df["rand_residual_weights"] = rand_residual_weights

# %%
# tweak l1 params if off
plt.plot(signal1, linestyle="--", alpha=0.5, color="blue")
plt.plot(signal2, linestyle="--", alpha=0.5,  color="red")
plt.plot(X_real[0],  linestyle="--", alpha=0.5)
plt.plot(test_df["test_signal"], linestyle="--", alpha=0.5)

plt.plot(test_df["expected_s_seas_mosek"], color="blue")
plt.plot(test_df["expected_s_hat_mosek"], color="red")

# %%
cols = test_df.columns 
test_df = pd.concat([test_df, pd.Series(rand_tv_weights)], ignore_index=True, axis=1)

test_df.columns = list(cols) + ["rand_tv_weights"]

# MOSEK
s_hat, s_seas = sd.l2_l1d1_l2d2p365(signal,  c1=2, solver = "MOSEK", residual_weights=test_df["rand_residual_weights"])
test_df["expected_s_hat_mosek_rw"] = s_hat
test_df["expected_s_seas_mosek_rw"] = s_seas

s_hat, s_seas = sd.l2_l1d1_l2d2p365(signal, c1=2.5, solver = "MOSEK", tv_weights=test_df["rand_tv_weights"].dropna())
test_df["expected_s_hat_mosek_tvw"] = s_hat
test_df["expected_s_seas_mosek_tvw"] = s_seas

# SCS
s_hat, s_seas = sd.l2_l1d1_l2d2p365(signal, c1=2.5, solver = "SCS", residual_weights=test_df["rand_residual_weights"])
test_df["expected_s_hat_scs_rw"] = s_hat
test_df["expected_s_seas_scs_rw"] = s_seas

s_hat, s_seas = sd.l2_l1d1_l2d2p365(signal, c1=2.5, solver = "SCS", tv_weights=test_df["rand_tv_weights"].dropna())
test_df["expected_s_hat_scs_tvw"] = s_hat
test_df["expected_s_seas_scs_tvw"] = s_seas
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [29], line 11
#       8 test_df["expected_s_hat_mosek_rw"] = s_hat
#       9 test_df["expected_s_seas_mosek_rw"] = s_seas
# ---> 11 s_hat, s_seas = sd.l2_l1d1_l2d2p365(signal, c1=2.5, solver = "MOSEK", tv_weights=test_df["rand_tv_weights"].dropna())
#      12 test_df["expected_s_hat_mosek_tvw"] = s_hat
#      13 test_df["expected_s_seas_mosek_tvw"] = s_seas
#
# File ~/Documents/SLAC/PVInsight/solar-data-tools/solardatatools/signal_decompositions.py:84, in l2_l1d1_l2d2p365(signal, c1, c2, solver, verbose, residual_weights, tv_weights, use_ixs, yearly_periodic, transition_locs, seas_max)
#      78 # w = len(signal) / np.sum(index_set)
#      79 if transition_locs is None: # this should be two separate sd problems
#      80     objective = cvx.Minimize(
#      81         # (365 * 3 / len(signal)) * w *
#      82         # cvx.sum(cvx.huber(cvx.multiply(residual_weights, s_error)))
#      83         10 * cvx.norm(cvx.multiply(residual_weights, s_error))
# ---> 84         + c1 * cvx.norm1(cvx.multiply(tv_weights, cvx.diff(s_hat, k=1)))
#      85         + c2 * cvx.norm(cvx.diff(s_seas, k=2))
#      86         # + c2 * .1 * cvx.norm(cvx.diff(s_seas, k=1))
#      87     )
#      88 else:
#      89     # This part cannot yet be implemented with osd+qss.
#      90     # Removes l1d1 cost (l1d1 penalty), instead uses index locations.
#      91     objective = cvx.Minimize(
#      92         10 * cvx.norm(cvx.multiply(residual_weights, s_error))
#      93         + c2 * cvx.norm(cvx.diff(s_seas, k=2))
#      94     )
#
# File ~/opt/anaconda3/envs/pvi-env/lib/python3.10/site-packages/cvxpy/atoms/affine/binary_operators.py:241, in multiply.__init__(self, lh_expr, rh_expr)
#     239 def __init__(self, lh_expr, rh_expr) -> None:
#     240     lh_expr, rh_expr = self.broadcast(lh_expr, rh_expr)
# --> 241     super(multiply, self).__init__(lh_expr, rh_expr)
#
# File ~/opt/anaconda3/envs/pvi-env/lib/python3.10/site-packages/cvxpy/atoms/affine/binary_operators.py:50, in BinaryOperator.__init__(self, lh_exp, rh_exp)
#      49 def __init__(self, lh_exp, rh_exp) -> None:
# ---> 50     super(BinaryOperator, self).__init__(lh_exp, rh_exp)
#
# File ~/opt/anaconda3/envs/pvi-env/lib/python3.10/site-packages/cvxpy/atoms/atom.py:51, in Atom.__init__(self, *args)
#      49 self.args = [Atom.cast_to_const(arg) for arg in args]
#      50 self.validate_arguments()
# ---> 51 self._shape = self.shape_from_args()
#      52 if len(self._shape) > 2:
#      53     raise ValueError("Atoms must be at most 2D.")
#
# File ~/opt/anaconda3/envs/pvi-env/lib/python3.10/site-packages/cvxpy/atoms/affine/binary_operators.py:278, in multiply.shape_from_args(self)
#     275 def shape_from_args(self) -> Tuple[int, ...]:
#     276     """The sum of the argument dimensions - 1.
#     277     """
# --> 278     return u.shape.sum_shapes([arg.shape for arg in self.args])
#
# File ~/opt/anaconda3/envs/pvi-env/lib/python3.10/site-packages/cvxpy/utilities/shape.py:48, in sum_shapes(shapes)
#      45 for t in shapes[1:]:
#      46     # Only allow broadcasting for 0D arrays or summation of scalars.
#      47     if shape != t and len(squeezed(shape)) != 0 and len(squeezed(t)) != 0:
# ---> 48         raise ValueError(
#      49             "Cannot broadcast dimensions " +
#      50             len(shapes)*" %s" % tuple(shapes))
#      52     longer = shape if len(shape) >= len(t) else t
#      53     shorter = shape if len(shape) < len(t) else t
#
# ValueError: Cannot broadcast dimensions  (729, 2) (729,)

# %%
#############################################################
# Take first 300 days of dataset
indices = list([True]*300) + list([False]*(len(signal)-300))

# MOSEK
s_hat, s_seas = sd.l2_l1d1_l2d2p365(signal, c1=2, solver = "MOSEK", use_ixs=indices)
test_df["expected_s_hat_mosek_ixs"] = s_hat
test_df["expected_s_seas_mosek_ixs"] = s_seas

# SCS
s_hat, s_seas = sd.l2_l1d1_l2d2p365(signal, c1=2, solver = "SCS", use_ixs=indices)
test_df["expected_s_hat_scs_ixs"] = s_hat
test_df["expected_s_seas_scs_ixs"] = s_seas

# %%
# tweak l1 params if off
plt.plot(signal1, linestyle="--", alpha=0.5, color="blue")
plt.plot(signal2, linestyle="--", alpha=0.5,  color="red")
plt.plot(X_real[0],  linestyle="--", alpha=0.5)
plt.plot(test_df["test_signal"], linestyle="--", alpha=0.5)

plt.plot(test_df["expected_s_hat_mosek_rw"], color="blue")
#plt.plot(test_df["expected_s_seas_scs_yearly_periodic"], color="blue", linestyle=":")

# %%
test_df = test_df.round(7)
test_df
# Out:
#      test_signal  expected_s_hat_mosek_365  expected_s_seas_mosek_365  \
# 0       1.070948                  0.964178                   0.045958
# 1       0.915023                  0.964178                   0.061677
# 2       1.070835                  0.964178                   0.077398
# 3       0.796580                  0.964178                   0.093120
# 4       1.181868                  0.964178                   0.108841
# ..           ...                       ...                        ...
# 725     1.060841                       NaN                        NaN
# 726     1.170515                       NaN                        NaN
# 727     0.770791                       NaN                        NaN
# 728     0.742476                       NaN                        NaN
# 729     1.110965                       NaN                        NaN
#
#      expected_s_hat_scs_365  expected_s_seas_scs_365  \
# 0                  0.955368                 0.056586
# 1                  0.955368                 0.072144
# 2                  0.955368                 0.087703
# 3                  0.955368                 0.103262
# 4                  0.955368                 0.118821
# ..                      ...                      ...
# 725                     NaN                      NaN
# 726                     NaN                      NaN
# 727                     NaN                      NaN
# 728                     NaN                      NaN
# 729                     NaN                      NaN
#
#      rand_residual_weights_365  rand_tv_weights_365  \
# 0                     1.901030             1.042992
# 1                     1.206654             1.586453
# 2                     1.492222             1.282554
# 3                     1.659901             1.175179
# 4                     1.820012             1.559077
# ..                         ...                  ...
# 725                        NaN                  NaN
# 726                        NaN                  NaN
# 727                        NaN                  NaN
# 728                        NaN                  NaN
# 729                        NaN                  NaN
#
#      expected_s_hat_mosek_rw_365  expected_s_seas_mosek_rw_365  \
# 0                       0.957599                      0.044934
# 1                       0.957599                      0.060643
# 2                       0.957599                      0.076357
# 3                       0.957599                      0.092078
# 4                       0.957599                      0.107810
# ..                           ...                           ...
# 725                          NaN                           NaN
# 726                          NaN                           NaN
# 727                          NaN                           NaN
# 728                          NaN                           NaN
# 729                          NaN                           NaN
#
#      expected_s_hat_mosek_tvw_365  ...  expected_s_hat_scs_seas_max  \
# 0                        0.923493  ...                     0.955788
# 1                        0.923493  ...                     0.955788
# 2                        0.923493  ...                     0.955788
# 3                        0.923493  ...                     0.955788
# 4                        0.923493  ...                     0.955788
# ..                            ...  ...                          ...
# 725                           NaN  ...                     0.609065
# 726                           NaN  ...                     0.609065
# 727                           NaN  ...                     0.609065
# 728                           NaN  ...                     0.609065
# 729                           NaN  ...                     0.609065
#
#      expected_s_seas_scs_seas_max  expected_s_hat_mosek_ixs  \
# 0                        0.318985                  1.076215
# 1                        0.326297                  1.076215
# 2                        0.333404                  1.076215
# 3                        0.340329                  1.076215
# 4                        0.347090                  1.076215
# ..                            ...                       ...
# 725                      0.276328                 -1.467238
# 726                      0.285516                 -1.467238
# 727                      0.294375                 -1.467238
# 728                      0.302932                 -1.467238
# 729                      0.311214                 -1.467238
#
#      expected_s_seas_mosek_ixs  expected_s_hat_scs_ixs  \
# 0                    -0.045410                1.078233
# 1                    -0.036171                1.078233
# 2                    -0.026881                1.078233
# 3                    -0.017542                1.078233
# 4                    -0.008157                1.078233
# ..                         ...                     ...
# 725                  -0.090353               -1.468650
# 726                  -0.081484               -1.468650
# 727                  -0.072559               -1.468650
# 728                  -0.063579               -1.468650
# 729                  -0.054547               -1.468650
#
#      expected_s_seas_scs_ixs  expected_s_hat_mosek_yearly_periodic  \
# 0                  -0.047198                              0.800014
# 1                  -0.038022                              0.800014
# 2                  -0.028795                              0.800014
# 3                  -0.019519                              0.800014
# 4                  -0.010197                              0.800014
# ..                       ...                                   ...
# 725                -0.091828                              0.800014
# 726                -0.083021                              0.800014
# 727                -0.074159                              0.800014
# 728                -0.065242                              0.800014
# 729                -0.056272                              0.800014
#
#      expected_s_seas_mosek_yearly_periodic  \
# 0                                 0.216540
# 1                                 0.233118
# 2                                 0.249636
# 3                                 0.266099
# 4                                 0.282511
# ..                                     ...
# 725                               0.132007
# 726                               0.149084
# 727                               0.166076
# 728                               0.182990
# 729                               0.199833
#
#      expected_s_hat_scs_yearly_periodic  expected_s_seas_scs_yearly_periodic
# 0                              0.800101                             0.216595
# 1                              0.800102                             0.233210
# 2                              0.800102                             0.249758
# 3                              0.800102                             0.266244
# 4                              0.800102                             0.282670
# ..                                  ...                                  ...
# 725                            0.800100                             0.131816
# 726                            0.800100                             0.148940
# 727                            0.800100                             0.165983
# 728                            0.800100                             0.182949
# 729                            0.800101                             0.199843
#
# [730 rows x 53 columns]

# %%
#test_df = test_df.astype(float).round(7)

# %%
test_df.to_csv(fname, float_format='%.7f')

# %% [markdown]
# # l1_l2d2p365

# %%
    """
    for a list of available solvers, see:
        https://www.cvxpy.org/tutorial/advanced/index.html#solve-method-options

    :param signal: 1d numpy array
    :param use_ixs: optional index set to apply cost function to
    :param c1: float
    :param solver: string
    :return: median fit with seasonal baseline removed
    """;

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from solardatatools import signal_decompositions as sd

np.random.seed(12) # reload each time to get first instance of seed

# %%
# smooth + yearly periodic + gaussian noise signals
t = np.linspace(0, 1000, 600)
signal1 = np.sin(2 * np.pi * t * 1 / (150)) # sine wave, smooth periodic

X_real = np.zeros((2, len(t)), dtype=float)
X_real[0] = 0.3 * np.random.randn(len(signal1)) # noise in form of sigma * np.random.randn(...) + mu
X_real[1] = signal1 


signal = np.sum(X_real, axis=0)

# %%
plt.plot(signal[:365])

# %%
# use_ixs=None, c1=1e3, yearly_periodic=True
# <365 and >365

# %%
fname = "test_l1_l2d2p365_data_input.csv"
try:
    signal = pd.read_csv(fname)["test_signal"].array
    test_df = pd.DataFrame(signal, columns=["test_signal"])
except FileNotFoundError:
    test_df = pd.DataFrame(signal, columns=["test_signal"])

# cvxpy output w/ default args

# MOSEK
s_hat, s_seas = sd.l1_l2d2p365(signal, solver = "MOSEK")
test_df["expected_s_hat_mosek"] = s_hat
test_df["expected_s_seas_mosek"] = s_seas

# SCS 
s_hat, s_seas = sd.l1_l2d2p365(signal, solver = "SCS")
test_df["expected_s_hat_scs"] = s_hat
test_df["expected_s_seas_scs"] = s_seas

#############################################################
# Take first year of dataset
indices = list([True]*365) + list([False]*235)

# MOSEK
s_hat, s_seas = sd.l2_l1d1_l2d2p365(signal, solver = "MOSEK", use_ixs=indices)
df_full["expected_s_hat_mosek_ixs"] = s_hat
df_full["expected_s_seas_mosek_ixs"] = s_seas

# SCS
s_hat, s_seas = sd.l2_l1d1_l2d2p365(signal, solver = "SCS", use_ixs=indices)
df_full["expected_s_hat_scs_ixs"] = s_hat
df_full["expected_s_seas_scs_ixs"] = s_seas

#############################################################
# yearly periodic constraint, len has to be >365

# MOSEK
s_hat, s_seas = sd.l2_l1d1_l2d2p365(signal, solver = "MOSEK", yearly_periodic=True)
df_full["expected_s_hat_mosek_yearly_periodic"] = s_hat
df_full["expected_s_seas_mosek_yearly_periodic"] = s_seas

# SCS
s_hat, s_seas = sd.l2_l1d1_l2d2p365(signal, solver = "SCS", yearly_periodic=True)
df_full["expected_s_hat_mosek_yearly_periodic"] = s_hat
df_full["expected_s_seas_mosek_yearly_periodic"] = s_seas
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [25], line 11
#       6     test_df = pd.DataFrame(signal, columns=["test_signal"])
#       8 # cvxpy output w/ default args
#       9
#      10 # MOSEK
# ---> 11 s_hat, s_seas = sd.l1_l2d2p365(signal, solver = "MOSEK")
#      12 test_df["expected_s_hat_mosek"] = s_hat
#      13 test_df["expected_s_seas_mosek"] = s_seas
#
# ValueError: too many values to unpack (expected 2)
