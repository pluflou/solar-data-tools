# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from solardatatools.solar_noon import avg_sunrise_sunset

# %%
with open('two_year_signal_fixed.csv') as file:
    data_fixed = np.loadtxt(file, delimiter=",")
with open('two_year_signal_with_shift.csv') as file:
    data_shifted = np.loadtxt(file, delimiter=',')

# %%
sns.heatmap(data_shifted);

# %%
sn = avg_sunrise_sunset(data_shifted)
plt.plot(sn);

# %%
sns.heatmap(data_fixed)
# Out:
# <AxesSubplot:>

# %%
sn = avg_sunrise_sunset(data_fixed)
plt.plot(sn);
